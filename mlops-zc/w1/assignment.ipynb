# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from tqdm import tqdm

# %%
os.getcwd()
# Out:
# '/workspaces/mlops-things/mlops-zc/w1'

# %%
# files = [('yellow_tripdata_2023-02.parquet', './data'), ('yellow_tripdata_2023-01.parquet', './data')]

# print("Download files:")
# for file, path in files:
#     url=f"https://d37ci6vzurychx.cloudfront.net/trip-data/{file}"
#     resp=requests.get(url, stream=True)
#     save_path=f"{path}/{file}"
#     with open(save_path, "wb") as handle:
#         for data in tqdm(resp.iter_content(),
#                         desc=f"{file}",
#                         postfix=f"save to {save_path}",
#                         total=int(resp.headers["Content-Length"])):
#             handle.write(data)

# %%
df_1 = pd.read_parquet('./data/yellow_tripdata_2023-01.parquet')
# df_2 = pd.read_parquet('./data/yellow_tripdata_2023-02.parquet')

# %%
df_1.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df_1.shape
# Out:
# (3066766, 19)

# %%
from datetime import datetime

# %%
df_1.tpep_pickup_datetime = pd.to_datetime(df_1.tpep_pickup_datetime)
df_1.tpep_dropoff_datetime = pd.to_datetime(df_1.tpep_dropoff_datetime)

# %%
df_1['duration'] = (df_1['tpep_dropoff_datetime'] - df_1['tpep_pickup_datetime'])
df_1['duration'] = df_1['duration'].dt.total_seconds() / 60

# %%
df_1
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1               2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2               2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3               1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4               2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
# ...           ...                  ...                   ...              ...
# 3066761         2  2023-01-31 23:58:34   2023-02-01 00:12:33              NaN
# 3066762         2  2023-01-31 23:31:09   2023-01-31 23:50:36              NaN
# 3066763         2  2023-01-31 23:01:05   2023-01-31 23:25:36              NaN
# 3066764         2  2023-01-31 23:40:00   2023-01-31 23:53:00              NaN
# 3066765         2  2023-01-31 23:07:32   2023-01-31 23:21:56              NaN
#
# ...

# %%
df_1.describe()
# Out:
#            VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  3.066766e+06                     3066766                     3066766
# mean   1.730215e+00  2023-01-17 00:22:26.288164  2023-01-17 00:38:06.427874
# min    1.000000e+00         2008-12-31 23:01:42         2009-01-01 14:29:11
# 25%    1.000000e+00  2023-01-09 16:21:57.250000         2023-01-09 16:37:06
# 50%    2.000000e+00  2023-01-17 08:42:29.500000  2023-01-17 08:58:30.500000
# 75%    2.000000e+00         2023-01-24 16:26:27         2023-01-24 16:42:49
# max    2.000000e+00         2023-02-01 00:56:53         2023-02-02 09:28:47
# std    4.438480e-01                         NaN                         NaN
#
#        passenger_count  trip_distance    RatecodeID  PULocationID  \
# count     2.995023e+06   3.066766e+06  2.995023e+06  3.066766e+06
# mean      1.362532e+00   3.847342e+00  1.497440e+00  1.663980e+02
# min       0.000000e+00   0.000000e+00  1.000000e+00  1.000000e+00
# ...

# %%
df_1_60 = df_1[(df_1.duration >= 1) & (df_1.duration <= 60)]
df_1_60.describe()
# Out:
#            VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  3.009173e+06                     3009173                     3009173
# mean   1.729855e+00  2023-01-17 00:34:19.090805  2023-01-17 00:48:31.382655
# min    1.000000e+00         2022-10-25 00:42:10         2022-10-25 00:44:22
# 25%    1.000000e+00         2023-01-09 16:26:19         2023-01-09 16:40:24
# 50%    2.000000e+00         2023-01-17 08:45:30         2023-01-17 08:59:46
# 75%    2.000000e+00         2023-01-24 16:33:29         2023-01-24 16:48:53
# max    2.000000e+00         2023-02-01 00:56:53         2023-02-01 01:06:43
# std    4.440346e-01                         NaN                         NaN
#
#        passenger_count  trip_distance    RatecodeID  PULocationID  \
# count     2.938068e+06   3.009173e+06  2.938068e+06  3.009173e+06
# mean      1.361619e+00   3.783685e+00  1.423694e+00  1.666243e+02
# min       0.000000e+00   0.000000e+00  1.000000e+00  1.000000e+00
# ...

# %%
df_1_60.shape[0]/df_1.shape[0] *100
# Out:
# 98.1220282212598

# %%
df_1.VendorID.unique()
# Out:
# array([2, 1])

# %%
categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

# %%
df_1_60[categorical] = df_1_60[categorical].astype(str)
# Out:
# /tmp/ipykernel_23638/511493597.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1_60[categorical] = df_1_60[categorical].astype(str)

# %%
df_1_60
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1               2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2               2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3               1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4               2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
# ...           ...                  ...                   ...              ...
# 3066761         2  2023-01-31 23:58:34   2023-02-01 00:12:33              NaN
# 3066762         2  2023-01-31 23:31:09   2023-01-31 23:50:36              NaN
# 3066763         2  2023-01-31 23:01:05   2023-01-31 23:25:36              NaN
# 3066764         2  2023-01-31 23:40:00   2023-01-31 23:53:00              NaN
# 3066765         2  2023-01-31 23:07:32   2023-01-31 23:21:56              NaN
#
# ...

# %%
from sklearn.feature_extraction import DictVectorizer

train_dicts = df_1_60[categorical + numerical].to_dict(orient='records')

# %%
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

# %%
X_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 9027519 stored elements and shape (3009173, 516)>

# %%
dv.get_feature_names_out()
# Out:
# array(['DOLocationID=1', 'DOLocationID=10', 'DOLocationID=100',
#        'DOLocationID=101', 'DOLocationID=102', 'DOLocationID=106',
#        'DOLocationID=107', 'DOLocationID=108', 'DOLocationID=109',
#        'DOLocationID=11', 'DOLocationID=111', 'DOLocationID=112',
#        'DOLocationID=113', 'DOLocationID=114', 'DOLocationID=115',
#        'DOLocationID=116', 'DOLocationID=117', 'DOLocationID=118',
#        'DOLocationID=119', 'DOLocationID=12', 'DOLocationID=120',
#        'DOLocationID=121', 'DOLocationID=122', 'DOLocationID=123',
#        'DOLocationID=124', 'DOLocationID=125', 'DOLocationID=126',
#        'DOLocationID=127', 'DOLocationID=128', 'DOLocationID=129',
#        'DOLocationID=13', 'DOLocationID=130', 'DOLocationID=131',
#        'DOLocationID=132', 'DOLocationID=133', 'DOLocationID=134',
#        'DOLocationID=135', 'DOLocationID=136', 'DOLocationID=137',
#        'DOLocationID=138', 'DOLocationID=139', 'DOLocationID=14',
# ...

# %%
dv.get_feature_names_out().shape
# Out:
# (516,)

# %%
target = 'duration'
y_train = df_1_60[target].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error
from sklearn.feature_extraction import DictVectorizer

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
import pickle

# %%
with open('./models/lr.bin', 'wb') as f_out:
    pickle.dump((dv, model), f_out)

# %%
model = pickle.load(open('./models/lr.bin', 'rb'))

# %%
dv, model = pickle.load(open('./models/lr.bin', 'rb'))

# %%
y_pred = model.predict(X_train)

# %%
y_pred
# Out:
# array([11.47419655, 10.94682493, 11.36738586, ..., 11.6683345 ,
#        12.70006847, 11.60926734], shape=(3009173,))

# %%
rmse = root_mean_squared_error(y_train, y_pred)
rmse
# Out:
# 7.658396898909143

# %%
df = pd.read_parquet('./data/yellow_tripdata_2023-02.parquet')
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-02-01 00:32:53   2023-02-01 00:34:34              2.0
# 1         2  2023-02-01 00:35:16   2023-02-01 00:35:30              1.0
# 2         2  2023-02-01 00:35:16   2023-02-01 00:35:30              1.0
# 3         1  2023-02-01 00:29:33   2023-02-01 01:01:38              0.0
# 4         2  2023-02-01 00:12:28   2023-02-01 00:25:46              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.30         1.0                  N           142           163
# 1           0.00         1.0                  N            71            71
# 2           0.00         1.0                  N            71            71
# 3          18.80         1.0                  N           132            26
# 4           3.22         1.0                  N           161           145
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
def prepare(df):
    df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
    df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])
    df['duration'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime'])
    df['duration'] = df['duration'].dt.total_seconds() / 60
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    
    categorical = ['PULocationID', 'DOLocationID']
    # numerical = ['trip_distance']
    
    df[categorical] = df[categorical].astype(str)
    return df

# %%
df = prepare(df)
# Out:
# /tmp/ipykernel_36764/931028533.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[categorical] = df[categorical].astype(str)

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2023-02-01 00:32:53   2023-02-01 00:34:34              2.0
# 3               1  2023-02-01 00:29:33   2023-02-01 01:01:38              0.0
# 4               2  2023-02-01 00:12:28   2023-02-01 00:25:46              1.0
# 5               1  2023-02-01 00:52:40   2023-02-01 01:07:18              1.0
# 6               1  2023-02-01 00:12:39   2023-02-01 00:40:36              1.0
# ...           ...                  ...                   ...              ...
# 2913950         2  2023-02-28 23:46:00   2023-03-01 00:05:00              NaN
# 2913951         2  2023-02-28 23:26:02   2023-02-28 23:37:10              NaN
# 2913952         2  2023-02-28 23:24:00   2023-02-28 23:38:00              NaN
# 2913953         2  2023-02-28 23:03:00   2023-02-28 23:10:00              NaN
# 2913954         2  2023-02-28 23:03:03   2023-02-28 23:12:51              NaN
#
# ...

# %%
categorical = ['PULocationID', 'DOLocationID']
X_val_dicts = df[categorical].to_dict(orient='records')

# %%
X_val = dv.transform(X_val_dicts)
y_val = df['duration'].values
y_pred = model.predict(X_val)
rmse = root_mean_squared_error(y_val, y_pred)
rmse
# Out:
# 7.820496959905137
